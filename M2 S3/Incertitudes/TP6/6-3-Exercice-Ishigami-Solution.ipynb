# %% [markdown]
# # Exercice : créer un métamodèle de krigeage pour la fonction Ishigami

# %%
import openturns as ot
from math import pi

# %% [markdown]
# ## Définition du modèle

# %%
ot.RandomGenerator.SetSeed(0)
formula = ['sin(X1) + 7. * sin(X2)^2 + 0.1 * X3^4 * sin(X1)']
input_names = ['X1', 'X2', 'X3']
g = ot.SymbolicFunction(input_names, formula)

# %%
distributionList = [ot.Uniform(-pi, pi)] * 3
distribution = ot.ComposedDistribution(distributionList)

# %% [markdown]
# ## Apprentissage

# %%
sampleSize_train = 200
X_train = distribution.getSample(sampleSize_train)
Y_train = g(X_train)

# %%
histo = ot.HistogramFactory().build(Y_train).drawPDF()
histo.setXTitle("Y")
histo.setTitle("Histogramme de la sortie")
histo.setLegends([""])
histo
# Out:
# class=Graph name=y0 PDF implementation=class=GraphImplementation name=y0 PDF title=Histogramme de la sortie xTitle=Y yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=10 drawables=[class=Drawable name=y0 PDF implementation=class=Curve name=y0 PDF derived from class=DrawableImplementation name=y0 PDF legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=44 dimension=2 data=[[-10.6334,0],[-9.47317,0],[-9.47317,0],[-9.47317,0.00430956],[-7.15275,0.00430956],[-7.15275,0],[-7.15275,0],[-7.15275,0.00646434],[-4.83232,0.00646434],[-4.83232,0],[-4.83232,0],[-4.83232,0.0172382],[-2.5119,0.0172382],[-2.5119,0],[-2.5119,0],[-2.5119,0.0581791],[-0.191479,0.0581791],[-0.191479,0],[-0.191479,0],[-0.191479,0.0905008],[2.12894,0.0905008],[2.12894,0],[2.12894,0],[2.12894,0.0818817],[4.44937,0.0818817],[4.44937,0],[4.44937,0],[4.44937,0.0948103],[6.76979,0.0948103],[6.76979,0],[6.76979,0],[6.76979,0.0560243],[9.09021,0.0560243],[9.09021,0],[9.09021,0],[9.09021,0.00861912],[11.4106,0.00861912],[11.4106,0],[11.4106,0],[11.4106,0.0129287],[13.7311,0.0129287],[13.7311,0],[13.7311,0],[14.8913,0]] color=#1f77b4 isColorExplicitlySet=false fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# ### Création du méta-modèle

# %%
dimension = distribution.getDimension()
basis = ot.ConstantBasisFactory(dimension).build()
covarianceModel = ot.SquaredExponential([1.]*dimension, [1.0])
algo = ot.KrigingAlgorithm(X_train, Y_train, covarianceModel, basis)
algo.run()
result = algo.getResult()
krigeageMM = result.getMetaModel()

# %%
result.getTrendCoefficients()
# Out:
# class=Point name=Unnamed dimension=1 values=[3.72318]

# %%
result.getCovarianceModel()
# Out:
# class=SquaredExponential scale=class=Point name=Unnamed dimension=3 values=[2.30465,1.81711,2.37813] amplitude=class=Point name=Unnamed dimension=1 values=[22.1341]

# %% [markdown]
# ## Validation

# %%
sampleSize_test = 100
X_test = distribution.getSample(sampleSize_test)
Y_test = g(X_test)

# %%
Y_test_MM = krigeageMM(X_test)

# %%
val = ot.MetaModelValidation(Y_test, Y_test_MM)

# %%
val.computeR2Score()
# Out:
# class=Point name=Unnamed dimension=1 values=[0.99231]

# %%
val.drawValidation()
# Out:
# class=GridLayout name=Unnamed nbRows=1 nbColumns=1 graphCollection=[class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=model 0 yTitle=metamodel axes=ON grid=ON legendposition= legendFontSize=10 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[-4.46695,-4.46695],[15.595,15.595]] color=#1f77b4 isColorExplicitlySet=false fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[2.74856,2.69844],[4.17994,4.18746],[4.86423,4.91269],[0.953576,0.959216],[5.32088,5.32433],[9.00219,9.42951],[4.00212,4.30234],[2.64371,2.66457],[6.17094,6.36582],[4.2475,4.7545],[2.26293,2.19902],[-0.769239,-0.691056],[5.73364,5.67201],[4.41694,4.42862],[3.47832,3.48834],[5.59714,5.67196],[6.80423,6.7506],[-3.71175,-3.72268],[7.87108,7.92945],[2.18488,2.18041],[3.12049,3.14342],[7.7528,7.71193],[2.36764,2.33714],[0.663825,0.675025],[9.15666,8.50519],[-3.86282,-3.92132],[5.6363,6.07273],[5.95867,5.92765],[3.1382,3.5467],[7.57847,7.60979],[-0.460816,-0.385896],[7.72485,7.70382],[4.95757,4.97844],[-2.34094,-2.37511],[0.719626,0.687823],[1.75842,1.83644],[10.7298,10.5988],[1.34522,1.28542],[1.18488,1.06033],[-1.39934,-1.45623],[5.15784,5.15281],[2.61398,2.59992],[4.97855,5.03503],[9.40036,9.14998],[2.59326,2.6176],[3.97983,3.97191],[6.86263,6.8603],[5.86252,5.81552],[1.23067,1.25308],[6.75413,6.72182],[1.78261,1.77846],[3.65971,3.65231],[5.79605,6.09357],[4.87254,3.56886],[12.2941,12.3286],[3.20307,3.156],[0.295699,0.285961],[1.91679,1.73099],[7.90794,7.97597],[2.72741,2.86743],[2.01743,1.9789],[3.85522,3.93673],[5.0008,4.78357],[2.04933,2.52797],[0.252053,0.219444],[-1.3232,-1.33431],[-0.00428016,0.106027],[6.30832,7.41384],[5.98945,5.85553],[1.44348,1.51787],[15.595,15.2285],[5.65996,5.75581],[3.01811,3.01043],[-0.970627,-0.975932],[11.7821,11.8698],[1.45316,1.64841],[4.93564,4.8996],[5.62997,5.65501],[11.2588,11.4606],[8.5378,9.07127],[7.05526,7.15737],[2.69659,2.83537],[6.76234,6.74805],[0.676866,0.73463],[7.67997,7.67525],[3.59664,3.47214],[5.95993,6.0085],[7.16166,7.13932],[10.9681,10.8874],[0.84977,0.799685],[0.593103,-0.0518597],[13.2823,13.2934],[5.59912,5.72432],[-4.46695,-4.42504],[2.62804,2.51281],[1.89874,2.45086],[8.23821,8.7564],[2.78843,3.80649],[1.68963,1.27509],[8.74377,10.447]] color=#ff7f0e isColorExplicitlySet=false fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]]

# %% [markdown]
# ## Analyse de sensibilité

# %%
alpha = 0.05 # i.e. 95% confidence interval
epsilon = 0.1 # Confidence interval length
blocksize = 50 # size of Sobol experiment at each iteration
batchsize = 16 # number of points evaluated simultaneously

# %%
estimator = ot.SaltelliSensitivityAlgorithm()
estimator.setUseAsymptoticDistribution(True)
algo = ot.SobolSimulationAlgorithm(distribution, krigeageMM, estimator)
algo.setMaximumOuterSampling(100) # number of iterations
algo.setBlockSize(blocksize) 
 
algo.setIndexQuantileLevel(alpha) # alpha
algo.setIndexQuantileEpsilon(epsilon) # epsilon
algo.run()

# %%
result = algo.getResult()
fo = result.getFirstOrderIndicesEstimate()
to = result.getTotalOrderIndicesEstimate()
print("First order = %s" % (str(fo)))
print("Total order = %s" % (str(to)))
# Out:
# First order = [0.279572,0.410103,-0.0122205]
# Total order = [0.569271,0.434434,0.24149]

# %%
def plotSobolSimulationResult(sobolSimulationResult, input_names, alpha=0.05):
    # 1. Récupération des données
    fo = sobolSimulationResult.getFirstOrderIndicesEstimate()
    to = sobolSimulationResult.getTotalOrderIndicesEstimate()
    
    dist_fo = sobolSimulationResult.getFirstOrderIndicesDistribution()
    dist_to = sobolSimulationResult.getTotalOrderIndicesDistribution()
    dim = dist_to.getDimension()
    
    graph = ot.Graph("Sobol' sensitivity indices", "Inputs", "Sensitivity indices", True, "topright")
    
    # 2. Préparation des axes X
    x_coords = ot.Sample([[i] for i in range(dim)])
    
    # 3. Préparation des Y (Indices) sous forme de Sample
    y_fo = ot.Sample([[v] for v in fo])
    y_to = ot.Sample([[v] for v in to])
    
    # 4. Tracé des nuages de points
    curve = ot.Cloud(x_coords, y_fo)
    curve.setColor("red")
    curve.setLegend("First order")
    curve.setPointStyle("bullet")
    graph.add(curve)
    
    curve = ot.Cloud(x_coords, y_to)
    curve.setColor("blue")
    curve.setLegend("Total order")
    curve.setPointStyle("bullet")
    graph.add(curve)
    
    # 5. Ajout des labels (CORRECTION ICI)
    for i in range(dim):
        # On crée un Sample de taille 1 contenant la coordonnée (X, Y)
        # X = i + 0.1 (décalage), Y = to[i]
        position = ot.Sample([[i + 0.1, to[i]]])
        
        # On met le nom dans une liste, car ot.Text attend une liste de labels
        label = [str(input_names[i])]
        
        text = ot.Text(position, label)
        text.setTextSize(1) # Optionnel: ajuste la taille si besoin
        text.setColor("black")
        graph.add(text)
    
    # 6. Barres d'erreur
    for i in range(dim):
        dist_fo_i = dist_fo.getMarginal(i)
        dist_to_i = dist_to.getMarginal(i)
        
        fo_ci = dist_fo_i.computeBilateralConfidenceInterval(1-alpha)
        to_ci = dist_to_i.computeBilateralConfidenceInterval(1-alpha)
        
        fo_a = fo_ci.getLowerBound()[0]
        fo_b = fo_ci.getUpperBound()[0]
        to_a = to_ci.getLowerBound()[0]
        to_b = to_ci.getUpperBound()[0]
        
        curve = ot.Curve([i, i], [fo_a, fo_b])
        curve.setColor("red")
        graph.add(curve)
        
        curve = ot.Curve([i, i], [to_a, to_b])
        curve.setColor("blue")
        graph.add(curve)
        
    return graph

# %%
inputDescription = g.getInputDescription()
plotSobolSimulationResult(result,inputDescription)
# Out:
# class=Graph name=Sobol' sensitivity indices implementation=class=GraphImplementation name=Sobol' sensitivity indices title=Sobol' sensitivity indices xTitle=Inputs yTitle=Sensitivity indices axes=ON grid=ON legendposition=topright legendFontSize=10 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=First order data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=3 dimension=2 data=[[0,0.279572],[1,0.410103],[2,-0.0122205]] color=red isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=bullet lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=Total order data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=3 dimension=2 data=[[0,0.569271],[1,0.434434],[2,0.24149]] color=blue isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=bullet lineWidth=1,class=Drawable name=Unnamed implementation=class=Text name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1 dimension=2 data=[[0.1,0.569271]] color=black isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Text name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1 dimension=2 data=[[1.1,0.434434]] color=black isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Text name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1 dimension=2 data=[[2.1,0.24149]] color=black isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0,0.241645],[0,0.317499]] color=red isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[0,0.523389],[0,0.615152]] color=blue isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[1,0.375998],[1,0.444208]] color=red isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[1,0.407111],[1,0.461756]] color=blue isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=2 dimension=2 data=[[2,-0.0519855],[2,0.0275446]] color=red isColorExplicitlySet=true fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Un ...

# %% [markdown]
# - On observe que la variable $X_1$, avec un indice de Sobol total proche de 0.6, est la variable qui possède le plus d'impact par elle même ou par ses interactions. En effet, sont indice du premier ordre est proche de 0.3, ce qui implique que les interactions entre $X_1$ et les autres variables comptent pour approximativement 30% de la variance totale.
# - La variable $X_2$ possède un indice du premier ordre proche de l'indice total, ce qui implique qu'elle n'interagit pas avec les autres variables. Son indice total est approximativement égal à 0.4.
# - La variable $X_3$ possède un indice du premier ordre proche de zéro. Elle a un impact sur la variabilité de la sortie uniquement via ses interactions avec les autres variables.
